# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as s

# %%
data = pd.read_csv(r"D:\new file d\NOTEBOOK\LUNG CANCER PREDICTION\survey lung cancer.csv")

# %%
print(f"Shape of The Dataset : {data.shape}")
print(f"\nGlimpse of The Dataset :")
data.head()
# Out:
# Shape of The Dataset : (309, 16)
#
# Glimpse of The Dataset :
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
data.describe(include=object)
# Out:
#        GENDER LUNG_CANCER
# count     309         309
# unique      2           2
# top         M         YES
# freq      162         270

# %%
data.isna().sum().to_frame()
# Out:
#                        0
# GENDER                 0
# AGE                    0
# SMOKING                0
# YELLOW_FINGERS         0
# ANXIETY                0
# PEER_PRESSURE          0
# CHRONIC DISEASE        0
# FATIGUE                0
# ALLERGY                0
# WHEEZING               0
# ALCOHOL CONSUMING      0
# COUGHING               0
# SHORTNESS OF BREATH    0
# SWALLOWING DIFFICULTY  0
# CHEST PAIN             0
# LUNG_CANCER            0

# %%
dup = data[data.duplicated()].shape[0]
print(f"There are {dup} duplicate entries among {data.shape[0]} entries in this dataset.")

data.drop_duplicates(keep='first',inplace=True)
print(f"\nAfter removing duplicate entries there are {data.shape[0]} entries in this dataset.")
# Out:
# There are 33 duplicate entries among 309 entries in this dataset.
#
# After removing duplicate entries there are 276 entries in this dataset.

# %%
data_temp = data.copy()
data_temp["GENDER"] = data_temp["GENDER"].replace({"M" : "Male" , "F" : "Female"})

for column in data_temp.columns:
    data_temp[column] = data_temp[column].replace({2: "Yes" , 1 : "No"})

data_temp.head()
# Out:
#    GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0    Male   69      No            Yes     Yes            No              No
# 1    Male   74     Yes             No      No            No             Yes
# 2  Female   59      No             No      No           Yes              No
# 3    Male   63     Yes            Yes     Yes            No              No
# 4  Female   63      No            Yes      No            No              No
#
#   FATIGUE  ALLERGY  WHEEZING ALCOHOL CONSUMING COUGHING SHORTNESS OF BREATH  \
# 0      Yes       No      Yes               Yes      Yes                 Yes
# 1      Yes      Yes       No                No       No                 Yes
# 2      Yes       No      Yes                No      Yes                 Yes
# 3       No       No       No               Yes       No                  No
# 4       No       No      Yes                No      Yes                 Yes
#
#   SWALLOWING DIFFICULTY CHEST PAIN LUNG_CANCER
# 0                   Yes        Yes         YES
# 1                   Yes        Yes         YES
# 2                    No        Yes          NO
# 3                   Yes        Yes          NO
# 4                    No         No          NO

# %%
s.set_style("whitegrid")
s.set_context("poster",font_scale = .7)

palette = ["#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#ffd100","#333533","#202020"]

# %%
data_temp_pos = data_temp[data_temp["LUNG_CANCER"] == "YES"]
data_temp_pos.head()
# Out:
#    GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0    Male   69      No            Yes     Yes            No              No
# 1    Male   74     Yes             No      No            No             Yes
# 5  Female   75      No            Yes      No            No             Yes
# 6    Male   52     Yes             No      No            No              No
# 7  Female   51     Yes            Yes     Yes           Yes              No
#
#   FATIGUE  ALLERGY  WHEEZING ALCOHOL CONSUMING COUGHING SHORTNESS OF BREATH  \
# 0      Yes       No      Yes               Yes      Yes                 Yes
# 1      Yes      Yes       No                No       No                 Yes
# 5      Yes      Yes      Yes                No      Yes                 Yes
# 6      Yes       No      Yes               Yes      Yes                 Yes
# 7      Yes      Yes       No                No       No                 Yes
#
#   SWALLOWING DIFFICULTY CHEST PAIN LUNG_CANCER
# 0                   Yes        Yes         YES
# 1                   Yes        Yes         YES
# 5                    No         No         YES
# 6                    No        Yes         YES
# 7                   Yes         No         YES

# %%
_, axs = plt.subplots(2,1,figsize=(20,10),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

s.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["AGE"],color=palette[11],kde=True,ax=axs[0],bins=20,alpha=1,fill=True)
axs[0].lines[0].set_color(palette[12])
axs[0].set_title("\nPositive Male Cases Age Distribution\n",fontsize=20)
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Quantity")

s.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["AGE"],color=palette[12],kde=True,ax=axs[1],bins=20,alpha=1,fill=True)
axs[1].lines[0].set_color(palette[11])
axs[1].set_title("\nPositive Female Cases Age Distribution\n",fontsize=20)
axs[1].set_xlabel("Age")
axs[1].set_ylabel("Quantity")

s.despine(left=True, bottom=True)
plt.show()

# %%
plt.subplots(figsize=(20, 8))
p = s.histplot(data=data_temp_pos,x="AGE",hue="GENDER",multiple="stack",palette=palette[11:13],kde=True,shrink=.99,bins=20,alpha=1,fill=True)
p.axes.lines[0].set_color(palette[11])
p.axes.lines[1].set_color(palette[12])
p.axes.set_title("\nPositive Cases Age Distribution\n",fontsize=20)
plt.ylabel("Count")
plt.xlabel("Age")

s.despine(left=True, bottom=True)
plt.show()

# %%
plt.subplots(figsize=(12, 12))

labels = "Male","Female"
size = 0.5

wedges, texts, autotexts = plt.pie([len(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["GENDER"]),
                                    len(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["GENDER"])],
                                    explode = (0,0),
                                    textprops=dict(size= 25, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.7,
                                    radius=.9, 
                                    colors = ["#0f4c5c","#FFC300"], 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "white", 
                                    linewidth = 5),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title("\nPositive Cases' Gender Distribution",fontsize=20)
plt.show()

# %%
_, axs = plt.subplots(1,2,figsize=(20,8),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

s.countplot(data=data_temp_pos,x="GENDER",hue="SMOKING",hue_order=["Yes","No"],ax=axs[0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0].set_title("\nEffect of Smoking\n",fontsize=20)
axs[0].set_xlabel("Gender")
axs[0].set_ylabel("Quantity")
for container in axs[0].containers:
    axs[0].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="ALCOHOL CONSUMING",hue_order=["Yes","No"],ax=axs[1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1].set_title("\nEffect of Alcohol Consuming\n",fontsize=20)
axs[1].set_xlabel("Gender")
axs[1].set_ylabel("Quantity")
for container in axs[1].containers:
    axs[1].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

s.despine(left=True, bottom=True)
plt.show()

# %%
_, axs = plt.subplots(2,5,figsize=(20,14),sharex=False,sharey=True)
plt.tight_layout(pad=4.0)

s.countplot(data=data_temp_pos,x="GENDER",hue="YELLOW_FINGERS",hue_order=["Yes","No"],ax=axs[0,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,0].set_ylabel("Total")
axs[0,0].legend(title="Yellow Fingers",loc="upper right")
for container in axs[0,0].containers:
    axs[0,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="ANXIETY",hue_order=["Yes","No"],ax=axs[0,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,1].set_ylabel("Total")
axs[0,1].legend(title="Anxiety",loc="upper right")
for container in axs[0,1].containers:
    axs[0,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="CHRONIC DISEASE",hue_order=["Yes","No"],ax=axs[0,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,2].set_ylabel("Total")
axs[0,2].legend(title="Chronic Disease",loc="upper right")
for container in axs[0,2].containers:
    axs[0,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="CHEST PAIN",hue_order=["Yes","No"],ax=axs[0,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,3].set_ylabel("Total")
axs[0,3].legend(title="Chest Pain",loc="upper right")
for container in axs[0,3].containers:
    axs[0,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="FATIGUE ",hue_order=["Yes","No"],ax=axs[0,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,4].set_ylabel("Total")
axs[0,4].legend(title="Fatigue",loc="upper right")
for container in axs[0,4].containers:
    axs[0,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="WHEEZING",hue_order=["Yes","No"],ax=axs[1,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,0].set_ylabel("Total")
axs[1,0].legend(title="Wheezing",loc="upper right")
for container in axs[1,0].containers:
    axs[1,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="COUGHING",hue_order=["Yes","No"],ax=axs[1,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,1].set_ylabel("Total")
axs[1,1].legend(title="Coughing",loc="upper right")
for container in axs[1,1].containers:
    axs[1,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="SHORTNESS OF BREATH",hue_order=["Yes","No"],ax=axs[1,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,2].set_ylabel("Total")
axs[1,2].legend(title="Short Breath",loc="upper right")
for container in axs[1,2].containers:
    axs[1,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

s.countplot(data=data_temp_pos,x="GENDER",hue="SWALLOWING DIFFICULTY",hue_order=["Yes","No"],ax=axs[1,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,3].set_ylabel("Total")
axs[1,3].legend(title="Swallowing Difficulty",loc="upper right")
for container in axs[1,3].containers:
    axs[1,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)    

s.countplot(data=data_temp_pos,x="GENDER",hue="ALLERGY ",hue_order=["Yes","No"],ax=axs[1,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,4].set_ylabel("Total")
axs[1,4].legend(title="Allergy",loc="upper right")
for container in axs[1,4].containers:
    axs[1,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)    

s.despine(left=True, bottom=True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()

data["GENDER"] = data["GENDER"].replace({"M" : "Male" , "F" : "Female"})
data["LUNG_CANCER"] = LabelEncoder.fit_transform(data["LUNG_CANCER"])

data = pd.get_dummies(data, columns= ["GENDER"])
data.rename(columns={"GENDER_Male" : "MALE", "GENDER_Female" : "FEMALE", "YELLOW_FINGERS" : "YELLOW FINGERS", "PEER_PRESSURE" : "PEER PRESSURE", "LUNG_CANCER" : "LUNG CANCER", "FATIGUE " : "FATIGUE", "ALLERGY " : "ALLERGY"}, inplace=True)
data = data[["AGE","MALE","FEMALE","ALCOHOL CONSUMING","CHEST PAIN","SHORTNESS OF BREATH","COUGHING","PEER PRESSURE","CHRONIC DISEASE","SWALLOWING DIFFICULTY","YELLOW FINGERS","ANXIETY","FATIGUE","ALLERGY","WHEEZING","LUNG CANCER"]]
data.head()
# Out:
#    AGE  MALE  FEMALE  ALCOHOL CONSUMING  CHEST PAIN  SHORTNESS OF BREATH  \
# 0   69     1       0                  2           2                    2
# 1   74     1       0                  1           2                    2
# 2   59     0       1                  1           2                    2
# 3   63     1       0                  2           2                    1
# 4   63     0       1                  1           1                    2
#
#    COUGHING  PEER PRESSURE  CHRONIC DISEASE  SWALLOWING DIFFICULTY  \
# 0         2              1                1                      2
# 1         1              1                2                      2
# 2         2              2                1                      1
# 3         1              1                1                      2
# 4         2              1                1                      1
#
#    YELLOW FINGERS  ANXIETY  FATIGUE  ALLERGY  WHEEZING  LUNG CANCER
# 0               2        2        2        1         2            1
# 1               1        1        2        2         1            1
# 2               1        1        2        1         2            0
# 3               2        2        1        1         1            0
# 4               2        1        1        1         2            0

# %%
plt.subplots(figsize =(16, 12))

p=s.heatmap(data.corr(), cmap = palette, square=True, cbar_kws=dict(shrink =.99), 
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
p.axes.set_title("Pearson Correlation Of Features\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %%
x = data.drop("LUNG CANCER", axis = 1)
y = data["LUNG CANCER"]

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

print(f"Shape of training data : {x_train.shape}, {y_train.shape}")
print(f"Shape of testing data : {x_test.shape}, {y_test.shape}")
# Out:
# Shape of training data : (220, 15), (220,)
# Shape of testing data : (56, 15), (56,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


lr = LogisticRegression()
lr.fit(x_train, y_train)
lr_pred = lr.predict(x_test)
lr_conf = confusion_matrix(y_test, lr_pred)
lr_report = classification_report(y_test, lr_pred)
lr_acc = round(accuracy_score(y_test, lr_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{lr_conf}")
print(f"\nClassification Report : \n\n{lr_report}")
print(f"\nThe Accuracy of Logistic Regression is {lr_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 5  7]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.42      0.59        12
#            1       0.86      1.00      0.93        44
#
#     accuracy                           0.88        56
#    macro avg       0.93      0.71      0.76        56
# weighted avg       0.89      0.88      0.85        56
#
#
# The Accuracy of Logistic Regression is 87.5 %

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(x_train, y_train)
gnb_pred = gnb.predict(x_test)
gnb_conf = confusion_matrix(y_test, gnb_pred)
gnb_report = classification_report(y_test, gnb_pred)
gnb_acc = round(accuracy_score(y_test, gnb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{gnb_conf}")
print(f"\nClassification Report : \n\n{gnb_report}")
print(f"\nThe Accuracy of Gaussian Naive Bayes is {gnb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 8  4]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.91      0.98      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.82      0.85        56
# weighted avg       0.91      0.91      0.91        56
#
#
# The Accuracy of Gaussian Naive Bayes is 91.07 %

# %%
from sklearn.naive_bayes import BernoulliNB

bnb = BernoulliNB()
bnb.fit(x_train, y_train)
bnb_pred = bnb.predict(x_test)
bnb_conf = confusion_matrix(y_test, bnb_pred)
bnb_report = classification_report(y_test, bnb_pred)
bnb_acc = round(accuracy_score(y_test, bnb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{bnb_conf}")
print(f"\nClassification Report : \n\n{bnb_report}")
print(f"\nThe Accuracy of Bernoulli Naive Bayes is {bnb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 8  4]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.91      0.98      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.82      0.85        56
# weighted avg       0.91      0.91      0.91        56
#
#
# The Accuracy of Bernoulli Naive Bayes is 91.07 %

# %%
from sklearn.svm import SVC

svm = SVC(C = 100, gamma = 0.002)
svm.fit(x_train, y_train)
svm_pred = svm.predict(x_test)
svm_conf = confusion_matrix(y_test, svm_pred)
svm_report = classification_report(y_test, svm_pred)
svm_acc = round(accuracy_score(y_test, svm_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{svm_conf}")
print(f"\nClassification Report : \n\n{svm_report}")
print(f"\nThe Accuracy of Support Vector Machine is {svm_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# The Accuracy of Support Vector Machine is 85.71 %

# %%
from sklearn.ensemble import RandomForestClassifier

rfg = RandomForestClassifier(n_estimators = 100, random_state = 42) 
rfg.fit(x_train, y_train)
rfg_pred = rfg.predict(x_test)
rfg_conf = confusion_matrix(y_test, rfg_pred)
rfg_report = classification_report(y_test, rfg_pred)
rfg_acc = round(accuracy_score(y_test, rfg_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{rfg_conf}")
print(f"\nClassification Report : \n\n{rfg_report}")
print(f"\nThe Accuracy of Random Forest Classifier is {rfg_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# The Accuracy of Random Forest Classifier is 85.71 %

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train, y_train)
knn_pred = knn.predict(x_test)
knn_conf = confusion_matrix(y_test, knn_pred)
knn_report = classification_report(y_test, knn_pred)
knn_acc = round(accuracy_score(y_test, knn_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{knn_conf}")
print(f"\nClassification Report : \n\n{knn_report}")
print(f"\nThe Accuracy of K Nearest Neighbors Classifier is {knn_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 9  3]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        12
#            1       0.93      0.98      0.96        44
#
#     accuracy                           0.93        56
#    macro avg       0.92      0.86      0.89        56
# weighted avg       0.93      0.93      0.93        56
#
#
# The Accuracy of K Nearest Neighbors Classifier is 92.86 %

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(use_label_encoder = False)
xgb.fit(x_train, y_train)
xgb_pred = xgb.predict(x_test)
xgb_conf = confusion_matrix(y_test, xgb_pred)
xgb_report = classification_report(y_test, xgb_pred)
xgb_acc = round(accuracy_score(y_test, xgb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{xgb_conf}")
print(f"\nClassification Report : \n\n{xgb_report}")
print(f"\nThe Accuracy of Extreme Gradient Boosting Classifier is {xgb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 7  5]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.58      0.74        12
#            1       0.90      1.00      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.95      0.79      0.84        56
# weighted avg       0.92      0.91      0.90        56
#
#
# The Accuracy of Extreme Gradient Boosting Classifier is 91.07 %
# C:\Users\Asus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\sklearn.py:1421: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

regularization_parameter = 0.003

neural_model = Sequential([tf.keras.layers.Dense(units=32, input_dim=(x_train.shape[-1]), activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=64, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=128, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dropout(0.3),
                    tf.keras.layers.Dense(units=16,activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=1, activation="sigmoid")
                    ])

print(neural_model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 32)                512
#
#  dense_6 (Dense)             (None, 64)                2112
#
#  dense_7 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 16)                2064
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 13,025
# Trainable params: 13,025
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get("accuracy") == 1.0):
            print("\nAccuracy is 100% so canceling training!")
            self.model.stop_training = True

callbacks = myCallback()


neural_model.compile(optimizer = Adam(learning_rate = 0.001), 
                     loss = "binary_crossentropy", 
                     metrics = ["accuracy"])

history = neural_model.fit(x_train, y_train,
                           epochs = 150,
                           verbose = 1,
                           batch_size = 64,
                           validation_data = (x_test, y_test),
                           callbacks = [callbacks])
# Out:
# Epoch 1/150
# 4/4 [==============================] - 2s 100ms/step - loss: 4.5179 - accuracy: 0.4136 - val_loss: 4.3908 - val_accuracy: 0.7143
# Epoch 2/150
# 4/4 [==============================] - 0s 19ms/step - loss: 4.3170 - accuracy: 0.8045 - val_loss: 4.2177 - val_accuracy: 0.7857
# Epoch 3/150
# 4/4 [==============================] - 0s 19ms/step - loss: 4.1153 - accuracy: 0.8818 - val_loss: 4.0648 - val_accuracy: 0.7857
# Epoch 4/150
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9526 - accuracy: 0.8818 - val_loss: 3.9351 - val_accuracy: 0.7857
# Epoch 5/150
# 4/4 [==============================] - 0s 19ms/step - loss: 3.8131 - accuracy: 0.8818 - val_loss: 3.8202 - val_accuracy: 0.7857
# Epoch 6/150
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6665 - accuracy: 0.8818 - val_loss: 3.7105 - val_accuracy: 0.7857
# Epoch 7/150
# 4/4 [==============================] - 0s 21ms/step - loss: 3.5368 - accuracy: 0.8818 - val_loss: 3.6031 - val_accuracy: 0.7857
# Epoch 8/150
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4095 - accuracy: 0.8818 - val_loss: 3.4940 - val_accuracy: 0.7857
# Epoch 9/150
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2904 - accuracy: 0.8818 - val_loss: 3.3849 - val_accuracy: 0.7857
# Epoch 10/150
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1721 - accuracy: 0.8818 - val_loss: 3.2742 - val_accuracy: 0.7857
# Epoch 11/150
# 4/4 [==============================] - 0s 21ms/step - loss: 3.0710 - accuracy: 0.8818 - val_loss: 3.1610 - val_accuracy: 0.7857
# Epoch 12/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.9594 - accuracy: 0.8818 - val_loss: 3.0467 - val_accuracy: 0.7857
# Epoch 13/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8347 - accuracy: 0.8818 - val_loss: 2.9327 - val_accuracy: 0.7857
# Epoch 14/150
# 4/4 [==============================] - 0s 21ms/step - loss: 2.7319 - accuracy: 0.8818 - val_loss: 2.8250 - val_accuracy: 0.7857
# Epoch 15/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.6325 - accuracy: 0.8818 - val_loss: 2.7189 - val_accuracy: 0.7857
# Epoch 16/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5311 - accuracy: 0.8818 - val_loss: 2.6154 - val_accuracy: 0.7857
# Epoch 17/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4362 - accuracy: 0.8818 - val_loss: 2.5156 - val_accuracy: 0.7857
# Epoch 18/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.3325 - accuracy: 0.8818 - val_loss: 2.4214 - val_accuracy: 0.7857
# Epoch 19/150
# 4/4 [==============================] - 0s 22ms/step - loss: 2.2431 - accuracy: 0.8818 - val_loss: 2.3329 - val_accuracy: 0.7857
# Epoch 20/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1542 - accuracy: 0.8818 - val_loss: 2.2446 - val_accuracy: 0.7857
# Epoch 21/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0703 - accuracy: 0.8818 - val_loss: 2.1575 - val_accuracy: 0.7857
# Epoch 22/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.9775 - accuracy: 0.8818 - val_loss: 2.0732 - val_accuracy: 0.7857
# Epoch 23/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.9004 - accuracy: 0.8818 - val_loss: 1.9869 - val_accuracy: 0.7857
# Epoch 24/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.8238 - accuracy: 0.8818 - val_loss: 1.9067 - val_accuracy: 0.7857
# Epoch 25/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.7431 - accuracy: 0.8818 - val_loss: 1.8298 - val_accuracy: 0.7857
# Epoch 26/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.6737 - accuracy: 0.8818 - val_loss: 1.7568 - val_accuracy: 0.7857
# Epoch 27/150
# 4/4 [==============================] - 0s 29ms/step - loss: 1.6020 - accuracy: 0.8818 - val_loss: 1.6881 - val_accuracy: 0.7857
# Epoch 28/150
# 4/4 [==============================] - 0s 27ms/step - loss: 1.5280 - accuracy: 0.8818 - val_loss: 1.6221 - val_accuracy: 0.7857
# Epoch 29/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4627 - accuracy: 0.8773 - val_loss: 1.5577 - val_accuracy: 0.7857
# Epoch 30/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.4010 - accuracy: 0.8864 - val_loss: 1.4927 - val_accuracy: 0.7857
# Epoch 31/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3359 - accuracy: 0.8864 - val_loss: 1.4298 - val_accuracy: 0.7857
# Epoch 32/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2779 - accuracy: 0.8909 - val_loss: 1.3719 - val_accuracy: 0.7857
# Epoch 33/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2229 - accuracy: 0.8909 - val_loss: 1.3157 - val_accuracy: 0.8036
# Epoch 34/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1652 - accuracy: 0.8909 - val_loss: 1.2641 - val_accuracy: 0.8036
# Epoch 35/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1143 - accuracy: 0.9045 - val_loss: 1.2140 - val_accuracy: 0.8393
# Epoch 36/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0666 - accuracy: 0.9000 - val_loss: 1.1655 - val_accuracy: 0.8393
# Epoch 37/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0218 - accuracy: 0.9091 - val_loss: 1.1178 - val_accuracy: 0.8393
# Epoch 38/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9732 - accuracy: 0.9000 - val_loss: 1.0755 - val_accuracy: 0.8393
# Epoch 39/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9424 - accuracy: 0.9000 - val_loss: 1.0349 - val_accuracy: 0.8393
# Epoch 40/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.8997 - accuracy: 0.9136 - val_loss: 0.9979 - val_accuracy: 0.8393
# Epoch 41/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8636 - accuracy: 0.9091 - val_loss: 0.9632 - val_accuracy: 0.8393
# Epoch 42/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8312 - accuracy: 0.9136 - val_loss: 0.9316 - val_accuracy: 0.8393
# Epoch 43/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7980 - accuracy: 0.9091 - val_loss: 0.9020 - val_accuracy: 0.8393
# Epoch 44/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7757 - accuracy: 0.9227 - val_loss: 0.8741 - val_accuracy: 0.8393
# Epoch 45/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7454 - accuracy: 0.9227 - val_loss: 0.8479 - val_accuracy: 0.8571
# Epoch 46/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7214 - accuracy: 0.9227 - val_loss: 0.8254 - val_accuracy: 0.8571
# Epoch 47/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.7010 - accuracy: 0.9136 - val_loss: 0.8032 - val_accuracy: 0.8571
# Epoch 48/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6843 - accuracy: 0.9273 - val_loss: 0.7815 - val_accuracy: 0.8750
# Epoch 49/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6611 - accuracy: 0.9227 - val_loss: 0.7630 - val_accuracy: 0.8750
# Epoch 50/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6438 - accuracy: 0.9227 - val_loss: 0.7454 - val_accuracy: 0.8750
# Epoch 51/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.6238 - accuracy: 0.9318 - val_loss: 0.7263 - val_accuracy: 0.8750
# Epoch 52/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6098 - accuracy: 0.9409 - val_loss: 0.7079 - val_accuracy: 0.8750
# Epoch 53/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5867 - accuracy: 0.9455 - val_loss: 0.6940 - val_accuracy: 0.8750
# Epoch 54/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5800 - accuracy: 0.9364 - val_loss: 0.6835 - val_accuracy: 0.8750
# Epoch 55/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5636 - accuracy: 0.9364 - val_loss: 0.6709 - val_accuracy: 0.8750
# Epoch 56/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5506 - accuracy: 0.9318 - val_loss: 0.6571 - val_accuracy: 0.8750
# Epoch 57/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5398 - accuracy: 0.9455 - val_loss: 0.6414 - val_accuracy: 0.8750
# Epoch 58/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5255 - accuracy: 0.9455 - val_loss: 0.6283 - val_accuracy: 0.8750
# Epoch 59/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5123 - accuracy: 0.9455 - val_loss: 0.6200 - val_accuracy: 0.8750
# Epoch 60/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5078 - accuracy: 0.9455 - val_loss: 0.6107 - val_accuracy: 0.8750
# Epoch 61/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5018 - accuracy: 0.9455 - val_loss: 0.6009 - val_accuracy: 0.8750
# Epoch 62/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4909 - accuracy: 0.9409 - val_loss: 0.5920 - val_accuracy: 0.8750
# Epoch 63/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4809 - accuracy: 0.9455 - val_loss: 0.5846 - val_accuracy: 0.8750
# Epoch 64/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4699 - accuracy: 0.9455 - val_loss: 0.5777 - val_accuracy: 0.8750
# Epoch 65/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.4609 - accuracy: 0.9455 - val_loss: 0.5695 - val_accuracy: 0.8750
# Epoch 66/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4545 - accuracy: 0.9455 - val_loss: 0.5616 - val_accuracy: 0.8750
# Epoch 67/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4499 - accuracy: 0.9455 - val_loss: 0.5533 - val_accuracy: 0.8750
# Epoch 68/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4444 - accuracy: 0.9455 - val_loss: 0.5457 - val_accuracy: 0.8750
# Epoch 69/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4383 - accuracy: 0.9409 - val_loss: 0.5393 - val_accuracy: 0.8750
# Epoch 70/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4340 - accuracy: 0.9545 - val_loss: 0.5314 - val_accuracy: 0.8750
# Epoch 71/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4251 - accuracy: 0.9500 - val_loss: 0.5269 - val_accuracy: 0.8750
# Epoch 72/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4199 - accuracy: 0.9455 - val_loss: 0.5204 - val_accuracy: 0.8750
# Epoch 73/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4118 - accuracy: 0.9545 - val_loss: 0.5159 - val_accuracy: 0.8750
# Epoch 74/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4077 - accuracy: 0.9455 - val_loss: 0.5124 - val_accuracy: 0.8750
# Epoch 75/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4025 - accuracy: 0.9455 - val_loss: 0.5092 - val_accuracy: 0.8750
# Epoch 76/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3971 - accuracy: 0.9500 - val_loss: 0.5049 - val_accuracy: 0.8750
# Epoch 77/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3965 - accuracy: 0.9545 - val_loss: 0.4993 - val_accuracy: 0.8750
# Epoch 78/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3921 - accuracy: 0.9545 - val_loss: 0.4969 - val_accuracy: 0.8750
# Epoch 79/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3841 - accuracy: 0.9500 - val_loss: 0.4949 - val_accuracy: 0.8750
# Epoch 80/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3814 - accuracy: 0.9545 - val_loss: 0.4894 - val_accuracy: 0.8750
# Epoch 81/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3775 - accuracy: 0.9545 - val_loss: 0.4849 - val_accuracy: 0.8750
# Epoch 82/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3801 - accuracy: 0.9545 - val_loss: 0.4820 - val_accuracy: 0.8750
# Epoch 83/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3769 - accuracy: 0.9545 - val_loss: 0.4815 - val_accuracy: 0.8750
# Epoch 84/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3668 - accuracy: 0.9455 - val_loss: 0.4800 - val_accuracy: 0.8750
# Epoch 85/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3668 - accuracy: 0.9500 - val_loss: 0.4747 - val_accuracy: 0.8750
# Epoch 86/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3667 - accuracy: 0.9500 - val_loss: 0.4694 - val_accuracy: 0.8750
# Epoch 87/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3586 - accuracy: 0.9545 - val_loss: 0.4659 - val_accuracy: 0.8750
# Epoch 88/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3567 - accuracy: 0.9545 - val_loss: 0.4655 - val_accuracy: 0.8750
# Epoch 89/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3503 - accuracy: 0.9500 - val_loss: 0.4645 - val_accuracy: 0.8750
# Epoch 90/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3508 - accuracy: 0.9500 - val_loss: 0.4616 - val_accuracy: 0.8750
# Epoch 91/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3457 - accuracy: 0.9591 - val_loss: 0.4599 - val_accuracy: 0.8750
# Epoch 92/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3420 - accuracy: 0.9591 - val_loss: 0.4555 - val_accuracy: 0.8750
# Epoch 93/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3436 - accuracy: 0.9591 - val_loss: 0.4505 - val_accuracy: 0.8929
# Epoch 94/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3389 - accuracy: 0.9545 - val_loss: 0.4480 - val_accuracy: 0.8750
# Epoch 95/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3412 - accuracy: 0.9545 - val_loss: 0.4455 - val_accuracy: 0.8750
# Epoch 96/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3339 - accuracy: 0.9545 - val_loss: 0.4444 - val_accuracy: 0.8750
# Epoch 97/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3305 - accuracy: 0.9545 - val_loss: 0.4376 - val_accuracy: 0.8929
# Epoch 98/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3302 - accuracy: 0.9591 - val_loss: 0.4351 - val_accuracy: 0.8929
# Epoch 99/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3294 - accuracy: 0.9545 - val_loss: 0.4343 - val_accuracy: 0.8929
# Epoch 100/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3275 - accuracy: 0.9545 - val_loss: 0.4334 - val_accuracy: 0.8750
# Epoch 101/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3233 - accuracy: 0.9545 - val_loss: 0.4306 - val_accuracy: 0.8929
# Epoch 102/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3223 - accuracy: 0.9545 - val_loss: 0.4259 - val_accuracy: 0.8929
# Epoch 103/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3176 - accuracy: 0.9545 - val_loss: 0.4249 - val_accuracy: 0.8929
# Epoch 104/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3140 - accuracy: 0.9545 - val_loss: 0.4231 - val_accuracy: 0.8929
# Epoch 105/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3090 - accuracy: 0.9545 - val_loss: 0.4239 - val_accuracy: 0.8929
# Epoch 106/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3125 - accuracy: 0.9545 - val_loss: 0.4242 - val_accuracy: 0.8750
# Epoch 107/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3073 - accuracy: 0.9545 - val_loss: 0.4239 - val_accuracy: 0.8929
# Epoch 108/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3069 - accuracy: 0.9545 - val_loss: 0.4189 - val_accuracy: 0.8929
# Epoch 109/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3065 - accuracy: 0.9545 - val_loss: 0.4188 - val_accuracy: 0.8929
# Epoch 110/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3018 - accuracy: 0.9591 - val_loss: 0.4175 - val_accuracy: 0.8929
# Epoch 111/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2985 - accuracy: 0.9545 - val_loss: 0.4147 - val_accuracy: 0.8929
# Epoch 112/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3004 - accuracy: 0.9545 - val_loss: 0.4109 - val_accuracy: 0.8929
# Epoch 113/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2981 - accuracy: 0.9545 - val_loss: 0.4050 - val_accuracy: 0.8929
# Epoch 114/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2991 - accuracy: 0.9500 - val_loss: 0.4044 - val_accuracy: 0.8929
# Epoch 115/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2974 - accuracy: 0.9545 - val_loss: 0.4064 - val_accuracy: 0.8929
# Epoch 116/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2937 - accuracy: 0.9591 - val_loss: 0.4057 - val_accuracy: 0.8750
# Epoch 117/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2897 - accuracy: 0.9591 - val_loss: 0.4038 - val_accuracy: 0.8750
# Epoch 118/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2874 - accuracy: 0.9545 - val_loss: 0.4011 - val_accuracy: 0.8750
# Epoch 119/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2858 - accuracy: 0.9636 - val_loss: 0.4003 - val_accuracy: 0.8750
# Epoch 120/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2833 - accuracy: 0.9591 - val_loss: 0.3980 - val_accuracy: 0.8750
# Epoch 121/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2865 - accuracy: 0.9591 - val_loss: 0.3959 - val_accuracy: 0.8929
# Epoch 122/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2844 - accuracy: 0.9545 - val_loss: 0.3941 - val_accuracy: 0.8929
# Epoch 123/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2792 - accuracy: 0.9682 - val_loss: 0.3931 - val_accuracy: 0.8929
# Epoch 124/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2809 - accuracy: 0.9636 - val_loss: 0.3922 - val_accuracy: 0.8929
# Epoch 125/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2788 - accuracy: 0.9545 - val_loss: 0.3892 - val_accuracy: 0.8929
# Epoch 126/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2767 - accuracy: 0.9591 - val_loss: 0.3885 - val_accuracy: 0.8929
# Epoch 127/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2730 - accuracy: 0.9636 - val_loss: 0.3874 - val_accuracy: 0.8929
# Epoch 128/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2756 - accuracy: 0.9591 - val_loss: 0.3835 - val_accuracy: 0.8929
# Epoch 129/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2750 - accuracy: 0.9545 - val_loss: 0.3825 - val_accuracy: 0.8929
# Epoch 130/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2678 - accuracy: 0.9591 - val_loss: 0.3811 - val_accuracy: 0.8929
# Epoch 131/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2725 - accuracy: 0.9591 - val_loss: 0.3810 - val_accuracy: 0.8929
# Epoch 132/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2694 - accuracy: 0.9591 - val_loss: 0.3808 - val_accuracy: 0.8929
# Epoch 133/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2681 - accuracy: 0.9591 - val_loss: 0.3774 - val_accuracy: 0.8929
# Epoch 134/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2640 - accuracy: 0.9636 - val_loss: 0.3756 - val_accuracy: 0.8929
# Epoch 135/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2694 - accuracy: 0.9591 - val_loss: 0.3709 - val_accuracy: 0.8929
# Epoch 136/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2670 - accuracy: 0.9591 - val_loss: 0.3710 - val_accuracy: 0.8929
# Epoch 137/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2641 - accuracy: 0.9591 - val_loss: 0.3705 - val_accuracy: 0.8929
# Epoch 138/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2625 - accuracy: 0.9636 - val_loss: 0.3714 - val_accuracy: 0.8929
# Epoch 139/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2616 - accuracy: 0.9591 - val_loss: 0.3733 - val_accuracy: 0.8929
# Epoch 140/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2622 - accuracy: 0.9545 - val_loss: 0.3722 - val_accuracy: 0.8929
# Epoch 141/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2623 - accuracy: 0.9500 - val_loss: 0.3691 - val_accuracy: 0.8929
# Epoch 142/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2565 - accuracy: 0.9591 - val_loss: 0.3694 - val_accuracy: 0.8929
# Epoch 143/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2563 - accuracy: 0.9636 - val_loss: 0.3708 - val_accuracy: 0.8929
# Epoch 144/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2576 - accuracy: 0.9591 - val_loss: 0.3718 - val_accuracy: 0.8929
# Epoch 145/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2556 - accuracy: 0.9545 - val_loss: 0.3711 - val_accuracy: 0.8929
# Epoch 146/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2514 - accuracy: 0.9682 - val_loss: 0.3690 - val_accuracy: 0.8929
# Epoch 147/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2524 - accuracy: 0.9591 - val_loss: 0.3690 - val_accuracy: 0.8929
# Epoch 148/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2493 - accuracy: 0.9682 - val_loss: 0.3659 - val_accuracy: 0.8929
# Epoch 149/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2512 - accuracy: 0.9636 - val_loss: 0.3681 - val_accuracy: 0.8929
# Epoch 150/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2500 - accuracy: 0.9591 - val_loss: 0.3701 - val_accuracy: 0.8929

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(len(acc)) # number of epochs

plt.figure(figsize=(20, 12))
plt.subplot(2,1,1)
plt.plot(epochs, acc, "yellow", label= "Training Accuracy")
plt.plot(epochs, val_acc, "black", label= "Validation Accuracy")
plt.title("Training and validation accuracy")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, loss, "yellow", label= "Training Loss")
plt.plot(epochs, val_loss, "black", label= "Validation Loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()
